# %%
import pandas as pd
import numpy as np
import math
from random import random

import imageio
import os

import matplotlib.pyplot as plt
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
def PointsInCircum(r,n=100):
    return np.array([(math.cos(2*np.pi/n*x)*r,math.sin(2*np.pi/n*x)*r) for x in range(0,n+1)])

def PointsInCircum2(r,n=100):
    points=[]
    for x in range(n):
        points.append((math.cos(2*np.pi/n*x)*(r+random()*(r/2)),math.sin(2*np.pi/n*x)*(r+random()*(r/2))))
    return np.array(points)

def rand_cluster(n,c,r):
    """returns n random points in disk of radius r centered at c"""
    x,y = c
    points = []
    for i in range(n):
        theta = 2*math.pi*random()
        s = r*random()
        points.append((x+s*math.cos(theta), 6*y+s*math.sin(theta)))
    return np.array(points)

# %%
def generate_data(n_samples):
#     n_samples = 1000
    X1 = PointsInCircum2(40,int(n_samples/2))
    X2 = rand_cluster(int(n_samples/2),(0,0),30)
#     plt.scatter(*X1.T)
#     plt.scatter(*X2.T)

    X = np.vstack([X1, X2])
    y0 = np.zeros(shape=(int(n_samples/2), 1))
    y1 = np.ones(shape=(int(n_samples/2), 1))
    yhat = np.vstack([y0, y1])
    return X, yhat

X, yhat = generate_data(1000)

# %%
def sig(z):
    return 1 / (1 + np.exp(-z))

def dsig_dz(z):
    return sig(z) * (1 - sig(z))

def J(y, yhat):
    eps = 1e-8
    return -(yhat*np.log(y+eps) + (1-yhat)*np.log(1-y+eps))

def dJ_dy(y, yhat):
    eps = 1e-8
    return (1-yhat)/(1-y+eps) - yhat/(y+eps)

def relu(z):
    return np.where(z>0, z, 0)
    
def drelu_dz(z):
    return np.where(z>0, 1, 0)

# %%
# 3 layers in network, nr of nodes in network:
n_input = 2
n_hidden = 10
n_out = 1

# %%
#initialize weights for input and hidden layers:
# size +1 for bias
w_0 = np.random.normal(0,0.1, size = (n_input+1,n_hidden)) #input layer
w_1 = np.random.normal(0,0.1, size = (n_hidden+1, n_out)) #hidden layer

w1 = np.random.normal(0,0.1, size=(n_input, n_hidden))
w2 = np.random.normal(0,0.1, size=(n_hidden, n_out))

b1 = np.random.normal(0,0.1, size=(n_hidden, 1))
b2 = np.random.normal(0,0.1, size=(n_out, 1))

# %%
def backwardJ(x0, w1, b1, w2, b2, y, yhat, alpha):
    # quantities
    z1 = np.dot(x0, w1) + b1.T
    x1 = relu(z1)
    z2 = np.dot(x1, w2) + b2.T
    #y = sig(z2)

    delta2 = dJ_dy(y, yhat) * dsig_dz(z2)
    delta1 = np.matmul(w2, delta2) * drelu_dz(z1).T

    w2 -= alpha * np.multiply(delta2, x1).T
    w1 -= alpha * np.multiply(delta1, x0).T

    b2 -= alpha * delta2
    b1 -= alpha * delta1
    
    return w1, b1, w2, b2

def prediction(x0, w1, b1, w2, b2):
    x1 = relu(np.dot(x0, w1) + b1.T)  # output of hidden layer
    return sig(np.dot(x1, w2) + b2.T)  # output of output layer

# %%
alpha=0.1

y = prediction(X[0], w1,b1,w2,b2)
w1, b1, w2, b2 = backwardJ(X[0], w1, b1, w2, b2, y, yhat[0], alpha)
print(y)
print(J(y, yhat[0]))
# Out:
# [[ 0.31407841]]
# [[ 0.37699195]]

# %%
def train_network(X, labels, step, nr_epochs,n_hidden): #implementation of pseudocode
    #initialize weights
    n_samples = X.shape[0]
    n_input = X.shape[1]
    n_output = 1
    costs = np.zeros(shape=(n_epoch,1))
#    X = input data
    w1 = np.random.normal(0,0.1, size=(n_input, n_hidden))
    w2 = np.random.normal(0,0.1, size=(n_hidden, n_out))

    b1 = np.random.normal(0,0.1, size=(n_hidden, 1))
    b2 = np.random.normal(0,0.1, size=(n_out, 1))
    
    for epoch in range(nr_epochs):
        for i, row in enumerate(X):
            y_pred = prediction(row,w1,b1,w2,b2)
            w1,b1,w2,b2 = backwardJ(row, w1, b1, w2, b2, y_pred, labels[i], step)
            
        howyoudoin = prediction(X, w1, b1, w2, b2)
        costs[epoch] = np.mean(J(howyoudoin, labels))
        
        if ((epoch % 10) == 0) or (epoch == (n_epoch - 1)):
            #print(predictions.round())
            accuracy = np.mean(howyoudoin.round() == yhat)  # current accuracy on entire set
            print('Training accuracy after epoch {}: {:.4%}'.format(epoch, accuracy))
            
    return w1, b1, w2, b2, costs

# %%
n_epoch = int(200)
n_hidden = 3
step = 0.001
w1, b1, w2, b2, costs = train_network(X, yhat ,step, n_epoch, n_hidden)
# Out:
# Training accuracy after epoch 0: 62.5000%
# Training accuracy after epoch 10: 50.4000%
# Training accuracy after epoch 20: 52.6000%
# Training accuracy after epoch 30: 59.7000%
# Training accuracy after epoch 40: 66.3000%
# Training accuracy after epoch 50: 70.8000%
# Training accuracy after epoch 60: 73.4000%
# Training accuracy after epoch 70: 77.3000%
# Training accuracy after epoch 80: 79.0000%
# Training accuracy after epoch 90: 81.8000%
# Training accuracy after epoch 100: 81.9000%
# Training accuracy after epoch 110: 82.2000%
# Training accuracy after epoch 120: 82.4000%
# Training accuracy after epoch 130: 82.7000%
# Training accuracy after epoch 140: 83.1000%
# Training accuracy after epoch 150: 83.4000%
# Training accuracy after epoch 160: 83.4000%
# Training accuracy after epoch 170: 83.9000%
# Training accuracy after epoch 180: 84.2000%
# Training accuracy after epoch 190: 83.9000%
# Training accuracy after epoch 199: 85.5000%

# %%
x1 = np.linspace(-60,60, 250)
x2 = np.linspace(-60,60, 250)
fun_map = np.empty((x1.size, x2.size))
for n,i in enumerate(x1):
    for m,j in enumerate(x2):
        fun_map[m,n] = prediction([i,j], w1, b1, w2, b2)

# %%
X0 = X[(yhat==0).reshape(-1)]
X1 = X[(yhat==1).reshape(-1)]

plt.figure(figsize=(10,5))
plt.imshow(fun_map, extent=[x1.min(), x1.max(), x2.min(), x2.max()], 
           vmin=0, vmax=1, aspect='auto')
plt.colorbar()
plt.scatter(*X0.T, label='0', alpha=0.4); plt.scatter(*X1.T, label='1', alpha=0.4)
plt.legend()

# %%
def train_network_wplots(X, labels, step, nr_epochs, n_hidden, RUN_LABEL): #implementation of pseudocode
    #initialize weights
    x1 = np.linspace(-65,65, 250)
    x2 = np.linspace(-65,65, 250)
    s=1
#     plt.figure(figsize=(20,30))
    
    n_samples = X.shape[0]
    n_input = X.shape[1]
    n_output = 1
    costs = np.zeros(shape=(n_epoch,1))
#    X = input data
    w1 = np.random.normal(0,0.1, size=(n_input, n_hidden))
    w2 = np.random.normal(0,0.1, size=(n_hidden, n_out))

    b1 = np.random.normal(0,0.1, size=(n_hidden, 1))
    b2 = np.random.normal(0,0.1, size=(n_out, 1))
    
    for epoch in range(nr_epochs):
        for i, row in enumerate(X):
            y_pred = prediction(row,w1,b1,w2,b2)
            w1,b1,w2,b2 = backwardJ(row, w1, b1, w2, b2, y, labels[i], step)
            
        howyoudoin = prediction(X, w1, b1, w2, b2)
        costs[epoch] = np.mean(J(howyoudoin, labels))
        
        if ((epoch % 5) == 0) or (epoch == (n_epoch - 1)):
            accuracy = np.mean(howyoudoin.round() == yhat)  # current accuracy on entire set
            print('Training accuracy after epoch {}: {:.4%}'.format(epoch, accuracy))
            fun_map = np.empty((x1.size, x2.size))
            for n,i in enumerate(x1):
                for m,j in enumerate(x2):
                    fun_map[m,n] = prediction([i,j], w1, b1, w2, b2)

            X0 = X[(yhat==0).reshape(-1)]
            X1 = X[(yhat==1).reshape(-1)]

#             plt.subplot(int(np.round(nr_epochs/10/2))+2,2,s)
            s+=1
            plt.imshow(fun_map, extent=[x1.min(), x1.max(), x2.min(), x2.max()], 
                       vmin=0, vmax=1, aspect='auto')
            plt.colorbar()
            plt.scatter(*X0.T, label='0', alpha=0.4); plt.scatter(*X1.T, label='1', alpha=0.4)
            plt.legend()
            plt.title('Epoch: {0}  Accuracy: {1}'.format(epoch,accuracy))
            plt.savefig('plots/frames/train_gif'+str(s)+str(RUN_LABEL)+'.png')
            plt.close()
            
    return w1, b1, w2, b2, costs, s

# %%
n_epoch = int(1000)
n_hidden = 4
step = 0.00001
RUN_LABEL = 'H'
w1, b1, w2, b2, costs, s = train_network_wplots(X, yhat,step, n_epoch, n_hidden, RUN_LABEL)
# Out:
# Training accuracy after epoch 0: 50.0000%
# Training accuracy after epoch 5: 50.0000%
# Training accuracy after epoch 10: 50.0000%
# Training accuracy after epoch 15: 50.0000%
# Training accuracy after epoch 20: 50.0000%
# Training accuracy after epoch 25: 50.0000%
# Training accuracy after epoch 30: 50.0000%
# Training accuracy after epoch 35: 63.7000%
# Training accuracy after epoch 40: 64.3000%
# Training accuracy after epoch 45: 63.0000%
# Training accuracy after epoch 50: 61.3000%
# Training accuracy after epoch 55: 62.8000%
# Training accuracy after epoch 60: 64.9000%
# Training accuracy after epoch 65: 66.5000%
# Training accuracy after epoch 70: 68.1000%
# Training accuracy after epoch 75: 69.6000%
# Training accuracy after epoch 80: 69.9000%
# Training accuracy after epoch 85: 70.5000%
# Training accuracy after epoch 90: 70.8000%
# Training accuracy after epoch 95: 71.1000%
# Training accuracy after epoch 100: 71.7000%
# Training accuracy after epoch 105: 72.3000%
# Training accuracy after epoch 110: 72.4000%
# Training accuracy after epoch 115: 72.8000%
# Training accuracy after epoch 120: 72.8000%
# Training accuracy after epoch 125: 72.4000%
# Training accuracy after epoch 130: 72.7000%
# Training accuracy after epoch 135: 72.1000%
# Training accuracy after epoch 140: 72.0000%
# Training accuracy after epoch 145: 71.9000%
# Training accuracy after epoch 150: 72.1000%
# Training accuracy after epoch 155: 72.1000%
# Training accuracy after epoch 160: 72.0000%
# Training accuracy after epoch 165: 72.2000%
# Training accuracy after epoch 170: 72.3000%
# Training accuracy after epoch 175: 72.5000%
# Training accuracy after epoch 180: 72.5000%
# Training accuracy after epoch 185: 72.5000%
# Training accuracy after epoch 190: 72.8000%
# Training accuracy after epoch 195: 73.0000%
# Training accuracy after epoch 200: 72.8000%
# Training accuracy after epoch 205: 73.2000%
# Training accuracy after epoch 210: 73.3000%
# Training accuracy after epoch 215: 73.5000%
# Training accuracy after epoch 220: 73.7000%
# Training accuracy after epoch 225: 73.9000%
# Training accuracy after epoch 230: 74.3000%
# Training accuracy after epoch 235: 75.1000%
# Training accuracy after epoch 240: 76.5000%
# Training accuracy after epoch 245: 78.1000%
# Training accuracy after epoch 250: 79.2000%
# Training accuracy after epoch 255: 80.3000%
# Training accuracy after epoch 260: 82.0000%
# Training accuracy after epoch 265: 83.1000%
# Training accuracy after epoch 270: 83.7000%
# Training accuracy after epoch 275: 84.0000%
# Training accuracy after epoch 280: 84.3000%
# Training accuracy after epoch 285: 84.4000%
# Training accuracy after epoch 290: 84.5000%
# Training accuracy after epoch 295: 84.6000%
# Training accuracy after epoch 300: 84.4000%
# Training accuracy after epoch 305: 84.5000%
# Training accuracy after epoch 310: 84.7000%
# Training accuracy after epoch 315: 84.7000%
# Training accuracy after epoch 320: 84.5000%
# Training accuracy after epoch 325: 84.2000%
# Training accuracy after epoch 330: 84.2000%
# Training accuracy after epoch 335: 84.3000%
# Training accuracy after epoch 340: 84.7000%
# Training accuracy after epoch 345: 84.9000%
# Training accuracy after epoch 350: 84.9000%
# Training accuracy after epoch 355: 85.1000%
# Training accuracy after epoch 360: 85.2000%
# Training accuracy after epoch 365: 85.3000%
# Training accuracy after epoch 370: 85.5000%
# Training accuracy after epoch 375: 85.9000%
# Training accuracy after epoch 380: 86.1000%
# Training accuracy after epoch 385: 86.3000%
# Training accuracy after epoch 390: 86.5000%
# Training accuracy after epoch 395: 86.6000%
# Training accuracy after epoch 400: 86.8000%
# Training accuracy after epoch 405: 86.8000%
# Training accuracy after epoch 410: 87.0000%
# Training accuracy after epoch 415: 87.1000%
# Training accuracy after epoch 420: 87.4000%
# Training accuracy after epoch 425: 87.7000%
# Training accuracy after epoch 430: 87.9000%
# Training accuracy after epoch 435: 87.9000%
# Training accuracy after epoch 440: 88.3000%
# Training accuracy after epoch 445: 88.8000%
# Training accuracy after epoch 450: 89.0000%
# Training accuracy after epoch 455: 89.4000%
# Training accuracy after epoch 460: 89.7000%
# Training accuracy after epoch 465: 90.3000%
# Training accuracy after epoch 470: 90.3000%
# Training accuracy after epoch 475: 90.4000%
# Training accuracy after epoch 480: 90.7000%
# Training accuracy after epoch 485: 91.2000%
# Training accuracy after epoch 490: 91.5000%
# Training accuracy after epoch 495: 91.7000%
# Training accuracy after epoch 500: 91.8000%
# Training accuracy after epoch 505: 91.8000%
# Training accuracy after epoch 510: 92.1000%
# Training accuracy after epoch 515: 92.1000%
# Training accuracy after epoch 520: 92.4000%
# Training accuracy after epoch 525: 92.5000%
# Training accuracy after epoch 530: 92.6000%
# Training accuracy after epoch 535: 92.6000%
# Training accuracy after epoch 540: 92.7000%
# Training accuracy after epoch 545: 92.8000%
# Training accuracy after epoch 550: 92.9000%
# Training accuracy after epoch 555: 92.9000%
# Training accuracy after epoch 560: 93.1000%
# Training accuracy after epoch 565: 93.3000%
# Training accuracy after epoch 570: 93.6000%
# Training accuracy after epoch 575: 93.8000%
# Training accuracy after epoch 580: 94.1000%
# Training accuracy after epoch 585: 94.3000%
# Training accuracy after epoch 590: 94.5000%
# Training accuracy after epoch 595: 94.5000%
# Training accuracy after epoch 600: 94.6000%
# Training accuracy after epoch 605: 94.6000%
# Training accuracy after epoch 610: 94.6000%
# Training accuracy after epoch 615: 94.7000%
# Training accuracy after epoch 620: 94.9000%
# Training accuracy after epoch 625: 95.1000%
# Training accuracy after epoch 630: 95.3000%
# Training accuracy after epoch 635: 95.3000%
# Training accuracy after epoch 640: 95.8000%
# Training accuracy after epoch 645: 96.0000%
# Training accuracy after epoch 650: 96.0000%
# Training accuracy after epoch 655: 96.1000%
# Training accuracy after epoch 660: 96.1000%
# Training accuracy after epoch 665: 96.2000%
# Training accuracy after epoch 670: 96.2000%
# Training accuracy after epoch 675: 96.3000%
# Training accuracy after epoch 680: 96.6000%
# Training accuracy after epoch 685: 97.0000%
# Training accuracy after epoch 690: 97.0000%
# Training accuracy after epoch 695: 97.0000%
# Training accuracy after epoch 700: 97.0000%
# Training accuracy after epoch 705: 97.0000%
# Training accuracy after epoch 710: 97.2000%
# Training accuracy after epoch 715: 97.5000%
# Training accuracy after epoch 720: 97.6000%
# Training accuracy after epoch 725: 97.7000%
# Training accuracy after epoch 730: 97.7000%
# Training accuracy after epoch 735: 97.7000%
# Training accuracy after epoch 740: 97.7000%
# Training accuracy after epoch 745: 97.8000%
# Training accuracy after epoch 750: 97.8000%
# Training accuracy after epoch 755: 97.8000%
# Training accuracy after epoch 760: 98.0000%
# Training accuracy after epoch 765: 98.0000%
# Training accuracy after epoch 770: 98.0000%
# Training accuracy after epoch 775: 98.2000%
# Training accuracy after epoch 780: 98.3000%
# Training accuracy after epoch 785: 98.4000%
# Training accuracy after epoch 790: 98.4000%
# Training accuracy after epoch 795: 98.5000%
# Training accuracy after epoch 800: 98.5000%
# Training accuracy after epoch 805: 98.6000%
# Training accuracy after epoch 810: 98.6000%
# Training accuracy after epoch 815: 98.8000%
# Training accuracy after epoch 820: 98.8000%
# Training accuracy after epoch 825: 98.8000%
# Training accuracy after epoch 830: 98.8000%
# Training accuracy after epoch 835: 98.9000%
# Training accuracy after epoch 840: 98.9000%
# Training accuracy after epoch 845: 99.0000%
# Training accuracy after epoch 850: 99.0000%
# Training accuracy after epoch 855: 99.0000%
# Training accuracy after epoch 860: 99.0000%
# Training accuracy after epoch 865: 99.0000%
# Training accuracy after epoch 870: 99.0000%
# Training accuracy after epoch 875: 99.0000%
# Training accuracy after epoch 880: 99.1000%
# Training accuracy after epoch 885: 99.1000%
# Training accuracy after epoch 890: 99.1000%
# Training accuracy after epoch 895: 99.1000%
# Training accuracy after epoch 900: 99.1000%
# Training accuracy after epoch 905: 99.1000%
# Training accuracy after epoch 910: 99.1000%
# Training accuracy after epoch 915: 99.1000%
# Training accuracy after epoch 920: 99.1000%
# Training accuracy after epoch 925: 99.2000%
# Training accuracy after epoch 930: 99.2000%
# Training accuracy after epoch 935: 99.2000%
# Training accuracy after epoch 940: 99.2000%
# Training accuracy after epoch 945: 99.2000%
# Training accuracy after epoch 950: 99.2000%
# Training accuracy after epoch 955: 99.2000%
# Training accuracy after epoch 960: 99.2000%
# Training accuracy after epoch 965: 99.2000%
# Training accuracy after epoch 970: 99.2000%
# Training accuracy after epoch 975: 99.2000%
# Training accuracy after epoch 980: 99.2000%
# Training accuracy after epoch 985: 99.3000%
# Training accuracy after epoch 990: 99.4000%
# Training accuracy after epoch 995: 99.4000%
# Training accuracy after epoch 999: 99.4000%

# %%
# Save the gif
# RUN_LABEL = 'G'
giffilename = 'train' +str(RUN_LABEL)

images = []

if os.path.isfile('plots/gifs/'+giffilename+ '.gif'):
    print("Don't overwrite the gif, ya doofus!")
else:
    for i in np.arange(2,s+1):
        filename = 'plots/frames/train_gif'+str(i)+str(RUN_LABEL)+'.png'
#         print(os.path.isfile(filename))
        
        images.append(imageio.imread(filename))
    imageio.mimsave('plots/gifs/'+giffilename+ '.gif', images)

# %% [markdown]
# $$ Step size = 0.001, epochs = 200$$
# <img src="plots/gifs/trainC.gif">

# %% [markdown]
# $$ Step size = 0.0001, epochs = 200$$
# <img src="plots/gifs/trainD.gif">

# %% [markdown]
# $$ Step size = 0.001, epochs = 400$$
# <img src="plots/gifs/trainE.gif">

# %% [markdown]
# $$ Step size = 0.0001, epochs = 400$$
# <img src="plots/gifs/trainF.gif">

# %% [markdown]
# $$ Step size = 0.0001, epochs = 400$$
# <img src="plots/gifs/trainG.gif">

# %% [markdown]
# $$ Step size = 0.00001, epochs = 1000$$
# <img src="plots/gifs/trainH.gif">

# %%
# clean up the folder.

if os.path.isfile('plots/gifs/'+giffilename+ '.gif'):
    for i in np.arange(2,42+1):
        filename = 'plots/frames/train_gif'+str(i)+str(RUN_LABEL)+'.png'
        os.remove(filename)
else:
    print("Save the gif first ya doofus!")

# %% [markdown]
# How does it do with other data?

# %%
Xtest, ytest = generate_data(n_samples = 1000)
pred_test = prediction(Xtest, w1, b1, w2, b2)

x1 = np.linspace(-65,65, 250)
x2 = np.linspace(-65,65, 250)

fun_map = np.empty((x1.size, x2.size))
for n,i in enumerate(x1):
    for m,j in enumerate(x2):
        fun_map[m,n] = prediction([i,j], w1, b1, w2, b2)

X0 = Xtest[(ytest==0).reshape(-1)]
X1 = Xtest[(ytest==1).reshape(-1)]

plt.figure(figsize=(20,10))
s+=1
plt.imshow(fun_map, extent=[x1.min(), x1.max(), x2.min(), x2.max()], 
           vmin=0, vmax=1, aspect='auto')
plt.colorbar()
plt.scatter(*X0.T, label='0', alpha=0.4); plt.scatter(*X1.T, label='1', alpha=0.4)
plt.legend()
plt.title("accuracy {0}".format(np.mean(pred_test.round() == ytest)))
plt.show()

# %% [markdown]
# Sharp decision boundary

# %%
fmap = np.round(fun_map,2)
fmap[fmap < 0.50] = 0
fmap[fmap > 0.50] = 0
fmap[fmap == 0.5] = 1

plt.imshow(fmap, extent=[x1.min(), x1.max(), x2.min(), x2.max()], 
           vmin=0, vmax=1, aspect='auto')
plt.colorbar()

# %%
np.round(np.max(X))*(0.4)
# Out:
# 2.4000000000000004

# %%
def train_network_sharp(X, labels, step, nr_epochs, n_hidden, RUN_LABEL, pr=True): #implementation of pseudocode
    #initialize weights
    xmin = np.round(np.min(X)) + np.round(np.min(X))*0.4
    xmax = np.round(np.max(X)) + np.round(np.max(X))*0.4
    
    x1 = np.linspace(xmin,xmax, 250)
    x2 = np.linspace(xmin,xmax, 250)
    s=1
#     plt.figure(figsize=(20,30))
    
    n_samples = X.shape[0]
    n_input = X.shape[1]
    n_output = 1
    costs = np.zeros(shape=(n_epoch,1))
#    X = input data
    w1 = np.random.normal(0,0.1, size=(n_input, n_hidden))
    w2 = np.random.normal(0,0.1, size=(n_hidden, n_out))

    b1 = np.random.normal(0,0.1, size=(n_hidden, 1))
    b2 = np.random.normal(0,0.1, size=(n_out, 1))
    
    for epoch in range(nr_epochs):
        for i, row in enumerate(X):
            y_pred = prediction(row,w1,b1,w2,b2)
            w1,b1,w2,b2 = backwardJ(row, w1, b1, w2, b2, y, labels[i], step)
            
        howyoudoin = prediction(X, w1, b1, w2, b2)
        costs[epoch] = np.mean(J(howyoudoin, labels))
        
        if ((epoch % 5) == 0) or (epoch == (n_epoch - 1)):
            accuracy = np.mean(howyoudoin.round() == yhat)  # current accuracy on entire set
            if pr == True:
                print('Training accuracy after epoch {}: {:.4%}'.format(epoch, accuracy))
            fun_map = np.empty((x1.size, x2.size))
            for n,i in enumerate(x1):
                for m,j in enumerate(x2):
                    fun_map[m,n] = prediction([i,j], w1, b1, w2, b2)
            # Create sharp boundary        
            fmap = np.round(fun_map,1)
            fmap[fmap < 0.50] = 0
            fmap[fmap > 0.50] = 0
            fmap[fmap == 0.5] = 1

            X0 = X[(yhat==0).reshape(-1)]
            X1 = X[(yhat==1).reshape(-1)]

            s+=1
            plt.figure(figsize=(13,5))
            plt.subplot(121)
            
            plt.imshow(fmap, extent=[x1.min(), x1.max(), x2.min(), x2.max()], 
                       vmin=0, vmax=1, aspect='auto', origin='lower')
            plt.colorbar()
            plt.scatter(*X0.T, label='0', alpha=0.4); plt.scatter(*X1.T, label='1', alpha=0.4)
            plt.legend()
            plt.title('Epoch: {0}  Accuracy: {1}'.format(epoch,accuracy))
    
            plt.subplot(122)
    
            plt.plot(costs[:epoch])
            plt.xlim((0,nr_epochs))
            plt.ylim((0,max(costs)))
            plt.title('Cost: {0}'.format(costs[epoch]))
            plt.savefig('plots/frames/train_gif'+str(s)+str(RUN_LABEL)+'.png')
            plt.close()
            
    return w1, b1, w2, b2, costs, s

# %%
n_epoch = int(300)
n_hidden = 4
step = 0.0001
RUN_LABEL = 'sharp'
w1, b1, w2, b2, costs, s = train_network_sharp(X, yhat,step, n_epoch, n_hidden, RUN_LABEL)
# Out:
# Training accuracy after epoch 0: 50.0000%
# Training accuracy after epoch 5: 62.0000%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-267-22642cf9b2a1> in <module>()
#       3 step = 0.0001
#       4 RUN_LABEL = 'sharp'
# ----> 5 w1, b1, w2, b2, costs, s = train_network_sharp(X, yhat,step, n_epoch, n_hidden, RUN_LABEL)
#
# <ipython-input-266-93a1e814610a> in train_network_sharp(X, labels, step, nr_epochs, n_hidden, RUN_LABEL)
#      20         for i, row in enumerate(X):
#      21             y_pred = prediction(row,w1,b1,w2,b2)
# ---> 22             w1,b1,w2,b2 = backwardJ(row, w1, b1, w2, b2, y, labels[i], step)
#      23
#      24         howyoudoin = prediction(X, w1, b1, w2, b2)
#
# <ipython-input-104-b64721691e41> in backwardJ(x0, w1, b1, w2, b2, y, yhat, alpha)
#      12     w1 -= alpha * np.multiply(delta1, x0).T
#      13
# ---> 14     b2 -= alpha * delta2
#      15     b1 -= alpha * delta1
#      16
#
# KeyboardInterrupt:

# %%
# Save the gif
# RUN_LABEL = 'G'
giffilename = 'train' +str(RUN_LABEL)

images = []

if os.path.isfile('plots/gifs/'+giffilename+ '.gif'):
    print("Don't overwrite the gif, ya doofus!")
else:
    for i in np.arange(2,s+1):
        filename = 'plots/frames/train_gif'+str(i)+str(RUN_LABEL)+'.png'
#         print(os.path.isfile(filename))
        
        images.append(imageio.imread(filename))
    imageio.mimsave('plots/gifs/'+giffilename+ '.gif', images)

# %% [markdown]
# $$ Step size = 0.0001, epochs = 300$$
# <img src="plots/gifs/trainsharp.gif">

# %%
n_epoch = int(300)
n_hidden = 4
step = 0.0001
RUN_LABEL = 'sharp3b'
w1, b1, w2, b2, costs, s = train_network_sharp(X, yhat,step, n_epoch, n_hidden, RUN_LABEL)
# Out:
# Training accuracy after epoch 0: 63.6000%
# Training accuracy after epoch 5: 69.7000%
# Training accuracy after epoch 10: 79.4000%
# Training accuracy after epoch 15: 80.2000%
# Training accuracy after epoch 20: 84.3000%
# Training accuracy after epoch 25: 88.8000%
# Training accuracy after epoch 30: 92.0000%
# Training accuracy after epoch 35: 94.6000%
# Training accuracy after epoch 40: 97.2000%
# Training accuracy after epoch 45: 98.6000%
# Training accuracy after epoch 50: 98.9000%
# Training accuracy after epoch 55: 99.3000%
# Training accuracy after epoch 60: 99.5000%
# Training accuracy after epoch 65: 99.6000%
# Training accuracy after epoch 70: 99.8000%
# Training accuracy after epoch 75: 99.7000%
# Training accuracy after epoch 80: 99.9000%
# Training accuracy after epoch 85: 99.9000%
# Training accuracy after epoch 90: 99.9000%
# Training accuracy after epoch 95: 100.0000%
# Training accuracy after epoch 100: 100.0000%
# Training accuracy after epoch 105: 100.0000%
# Training accuracy after epoch 110: 100.0000%
# Training accuracy after epoch 115: 100.0000%
# Training accuracy after epoch 120: 100.0000%
# Training accuracy after epoch 125: 100.0000%
# Training accuracy after epoch 130: 100.0000%
# Training accuracy after epoch 135: 99.9000%
# Training accuracy after epoch 140: 100.0000%
# Training accuracy after epoch 145: 100.0000%
# Training accuracy after epoch 150: 99.9000%
# Training accuracy after epoch 155: 99.9000%
# Training accuracy after epoch 160: 99.8000%
# Training accuracy after epoch 165: 99.6000%
# Training accuracy after epoch 170: 99.4000%
# Training accuracy after epoch 175: 99.6000%
# Training accuracy after epoch 180: 99.6000%
# Training accuracy after epoch 185: 99.6000%
# Training accuracy after epoch 190: 99.7000%
# Training accuracy after epoch 195: 99.6000%
# Training accuracy after epoch 200: 99.6000%
# Training accuracy after epoch 205: 99.7000%
# Training accuracy after epoch 210: 99.6000%
# Training accuracy after epoch 215: 99.7000%
# Training accuracy after epoch 220: 99.6000%
# Training accuracy after epoch 225: 99.6000%
# Training accuracy after epoch 230: 99.4000%
# Training accuracy after epoch 235: 99.1000%
# Training accuracy after epoch 240: 99.2000%
# Training accuracy after epoch 245: 99.3000%
# Training accuracy after epoch 250: 99.2000%
# Training accuracy after epoch 255: 99.1000%
# Training accuracy after epoch 260: 99.5000%
# Training accuracy after epoch 265: 99.4000%
# Training accuracy after epoch 270: 99.3000%
# Training accuracy after epoch 275: 99.2000%
# Training accuracy after epoch 280: 99.3000%
# Training accuracy after epoch 285: 98.9000%
# Training accuracy after epoch 290: 99.0000%
# Training accuracy after epoch 295: 99.3000%
# Training accuracy after epoch 299: 99.2000%

# %%
# Save the gif
# RUN_LABEL = 'G'
def save_as_gif(label, overwrite=False, remove_files=False):
    giffilename = 'train' +str(label)

    images = []

    if (os.path.isfile('plots/gifs/'+giffilename+ '.gif'))&(overwrite==False):
        print("Don't overwrite the gif, ya doofus!")
    else:
        for i in np.arange(2,s+1):
            filename = 'plots/frames/train_gif'+str(i)+str(RUN_LABEL)+'.png'
            images.append(imageio.imread(filename))
            if remove_files==True:
                os.remove(filename)
        imageio.mimsave('plots/gifs/'+giffilename+ '.gif', images)

# %%
save_as_gif(RUN_LABEL, remove_files=True)

# %% [markdown]
# <img src="plots/gifs/trainsharp2.gif">

# %% [markdown]
# <img src="plots/gifs/trainsharp3.gif">

# %% [markdown]
# <img src="plots/gifs/trainsharp3b.gif">

# %% [markdown]
# Let's try these with the other datasets

# %%
def rescale(X):
    return (X - X.mean(axis=0)) / (X.var(axis=0))

n_samples = 1000
X0 = np.random.normal(loc=[0,0], scale=[2,0.5], size=(int(n_samples/2), 2))
X11 = np.random.normal(loc=[0,3.5], scale=[0.5,1], size=(int(n_samples/4), 2))
X12 = np.random.normal(loc=[0,-3.5], scale=[0.5,1], size=(int(n_samples/4), 2))
X1 = np.vstack([X11, X12])
X = np.vstack([X0, X1])

# X = rescale(X)

y0 = np.zeros(shape=(int(n_samples/2), 1))
y1 = np.ones(shape=(int(n_samples/2), 1))
yhat = np.vstack([y0, y1])

# %%
n_epoch = int(300)
n_hidden = 4
step = 0.001
RUN_LABEL = 'sharp6'
w1, b1, w2, b2, costs, s = train_network_sharp(X, yhat,step, n_epoch, n_hidden, RUN_LABEL,pr=False)

# %%
save_as_gif(RUN_LABEL, overwrite=True, remove_files = True)

# %% [markdown]
# <img src='plots/gifs/trainsharp5.gif'>

# %% [markdown]
# <img src='plots/gifs/trainsharp6.gif'>

# %% [markdown]
# let's clean up that plot code because it's getting out of hand

# %%
def Trainnetwork(X, labels, step, nr_epochs, n_hidden, RUN_LABEL, pr=True, style = 'flow', thickness = 1): #implementation of pseudocode

    s=1
    
    n_samples = X.shape[0]
    n_input = X.shape[1]
    n_output = 1
    
    costs = np.zeros(shape=(n_epoch,1))

    w1 = np.random.normal(0,0.1, size=(n_input, n_hidden))
    w2 = np.random.normal(0,0.1, size=(n_hidden, n_out))

    b1 = np.random.normal(0,0.1, size=(n_hidden, 1))
    b2 = np.random.normal(0,0.1, size=(n_out, 1))
    
    for epoch in range(nr_epochs):
        for i, row in enumerate(X):
            y_pred = prediction(row,w1,b1,w2,b2)
            w1,b1,w2,b2 = backwardJ(row, w1, b1, w2, b2, y_pred, labels[i], step)
            
        howyoudoin = prediction(X, w1, b1, w2, b2)
        costs[epoch] = np.mean(J(howyoudoin, labels))
        
        if ((epoch % 5) == 0) or (epoch == (n_epoch - 1)):
            accuracy = np.mean(howyoudoin.round() == yhat)  # current accuracy on entire set
            if pr == True:
                print('Training accuracy after epoch {}: {:.4%}'.format(epoch, accuracy))
            weights = (w1, b1, w2, b2)
            s = save_iter_image(X, weights, costs, s, epoch, accuracy, nr_epochs, style, thickness)
            
    giffilename = save_as_gif(RUN_LABEL, overwrite=True, remove_files = True) 
    print('Saved gif {0}'.format(giffilename))
    print('<img src=plots/gifs/'+giffilename+'.gif>')
    return w1, b1, w2, b2, costs, s

def save_iter_image(X, weights, costs, s, epoch, accuracy, nr_epochs, style='flow', thickness = 1):
    import matplotlib.cm as cm
    
    w1, b1, w2, b2 = weights
    
    # Define the colormap:    
    xmin = np.round(np.min(X)) + np.round(np.min(X))*0.4
    xmax = np.round(np.max(X)) + np.round(np.max(X))*0.4
    
    x1 = np.linspace(xmin,xmax, 250)
    x2 = np.linspace(xmin,xmax, 250)
    
    fun_map = np.empty((x1.size, x2.size))
    for n,i in enumerate(x1):
        for m,j in enumerate(x2):
            fun_map[m,n] = prediction([i,j], w1, b1, w2, b2)
            
    # Create sharp boundary if that is the option  
    if style == 'sharp':
        fmap = np.round(fun_map,thickness)
        fmap[fmap < 0.50] = 0
        fmap[fmap > 0.50] = 0.5
        fmap[fmap == 0.5] = 1
    elif style == 'flow':
        fmap = fun_map

    X0 = X[(yhat==0).reshape(-1)]
    X1 = X[(yhat==1).reshape(-1)]

    s+=1
    plt.figure(figsize=(13,5))
    
    plt.subplot(121)

    plt.imshow(fmap, extent=[x1.min(), x1.max(), x2.min(), x2.max()], 
               vmin=0, vmax=1, aspect='auto', origin='lower')
    plt.scatter(*X0.T, label='0', alpha=0.4); 
    plt.scatter(*X1.T, label='1', alpha=0.4);
    m = cm.ScalarMappable(cmap=cm.viridis)
    m.set_array(fmap)
    plt.colorbar(m)
    plt.legend()
#     plt.colorbar()
    plt.title('Epoch: {0}  Accuracy: {1}'.format(epoch,accuracy))

    plt.subplot(122)

    plt.plot(costs[:epoch])
    plt.xlim((0,nr_epochs))
    plt.ylim((0,max(costs)))
    plt.title('Cost: {0}'.format(costs[epoch]))
    plt.savefig('plots/frames/train_gif'+str(s)+str(RUN_LABEL)+'.png')
    plt.close()
    
    return s

def save_as_gif(label, overwrite=True, remove_files=False):
    giffilename = 'train' +str(label)

    images = []

    if (os.path.isfile('plots/gifs/'+giffilename+ '.gif'))&(overwrite==False):
        print("Don't overwrite the gif, ya doofus!")
    else:
        for i in np.arange(2,s+1):
            filename = 'plots/frames/train_gif'+str(i)+str(RUN_LABEL)+'.png'
            images.append(imageio.imread(filename))
            if remove_files==True:
                os.remove(filename)
        imageio.mimsave('plots/gifs/'+giffilename+ '.gif', images)
        
    return giffilename

# %%
n_epoch = int(300)
n_hidden = 4
step = 0.0001
RUN_LABEL = 'newfunctest3'
w1, b1, w2, b2, costs, s = Trainnetwork(X, yhat,step, n_epoch, n_hidden, 
                                        RUN_LABEL,pr=False,style='flow',thickness=1)
# Out:
# Saved gif trainnewfunctest3
# <img src=plots/gifs/trainnewfunctest3.gif>

# %% [markdown]
# <img src=plots/gifs/trainnewfunctest.gif>

# %% [markdown]
# <img src=plots/gifs/trainnewfunctest2.gif>

# %% [markdown]
# <img src=plots/gifs/trainnewfunctest3.gif>

# %%
n_epoch = int(300)
n_hidden = 4
step = 0.0001
RUN_LABEL = 'newfunctest_sharp'
w1, b1, w2, b2, costs, s = Trainnetwork(X, yhat,step, n_epoch, n_hidden, 
                                        RUN_LABEL,pr=False,style='sharp',thickness=1)
# Out:
# Saved gif trainnewfunctest_sharp
# <img src=plots/gifs/trainnewfunctest_sharp.gif>

# %% [markdown]
# <img src=plots/gifs/trainnewfunctest_sharp.gif>

# %%
A = rand_cluster(500,(1,1),3)
B = rand_cluster(500,(4,2),3)
X = np.vstack([A,B])

y0 = np.zeros((len(A),1))
y1 = np.ones((len(A),1))
yhat = np.vstack([y0,y1])

# %%
n_epoch = int(300)
n_hidden = 4
step = 0.0001
RUN_LABEL = 'otherset'
w1, b1, w2, b2, costs, s = Trainnetwork(X, yhat,step, n_epoch, n_hidden, 
                                        RUN_LABEL,pr=False,style='flow',thickness=2)
# Out:
# Saved gif trainotherset
# <img src=plots/gifs/trainotherset.gif>

# %% [markdown]
# <img src=plots/gifs/trainotherset.gif>
